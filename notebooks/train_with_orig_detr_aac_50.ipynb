# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import os
import numpy as np
import torch
from pathlib import Path

print(torch.__version__)
# Out:
# 1.9.0+cu111

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# The GPU id to use, "0" to  "7"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
torch.cuda.empty_cache()

# %%
# !git clone https://github.com/facebookresearch/detr.git

# %%
# import sys

# if os.path.join(os.getcwd(), "detr/") not in sys.path:
#     sys.path.append(os.path.join(os.getcwd(), "detr/"))

# print(sys.path)

# %%
# !wget https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth

# %%
# !python3 detr/main.py --dataset_file construction --epochs 50 --data_path /home/ammar/projects/construction/data --output_dir /home/ammar/projects/construction/data/output_08_09_2022 --resume detr/weights/detr-r50-e632da11.pth
# Out:
# Not using distributed mode
# git:
#   sha: eb9f7e03ed8e2ed2cd55528989fe7df890bc3fc0, status: has uncommited changes, branch: main
#
# Namespace(aux_loss=True, backbone='resnet50', batch_size=2, bbox_loss_coef=5, clip_max_norm=0.1, coco_panoptic_path=None, data_path='/home/ammar/projects/construction/data', dataset_file='construction', dec_layers=6, device='cuda', dice_loss_coef=1, dilation=False, dim_feedforward=2048, dist_url='env://', distributed=False, dropout=0.1, enc_layers=6, eos_coef=0.1, epochs=50, eval=False, frozen_weights=None, giou_loss_coef=2, hidden_dim=256, lr=0.0001, lr_backbone=1e-05, lr_drop=200, mask_loss_coef=1, masks=False, nheads=8, num_queries=20, num_workers=2, output_dir='/home/ammar/projects/construction/data/output', position_embedding='sine', pre_norm=False, remove_difficult=False, resume='detr/weights/detr-r50-e632da11.pth', seed=42, set_cost_bbox=5, set_cost_class=1, set_cost_giou=2, start_epoch=0, weight_decay=0.0001, world_size=1)
# ...

# %%
torch.cuda.empty_cache()
